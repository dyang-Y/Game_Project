# %%
# !pip install selenium

# %%
from selenium import webdriver
# Out:
# /Users/yang_daeun/github_blog/mini_project/mini_project/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()

driver.get('https://store.steampowered.com/charts/topselling/KR')

# %%
driver.find_elements(By.CSS_SELECTOR, 'table._3arZn0BMPzyhcYNADe193m')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9b6a90fdba75f2c786b0780cb619c11b", element="f.8F88E99CC3165FB1257CAE3F6231D7CF.d.34152C1241890A966CA6016447D08FB7.e.231")>]

# %%
element = driver.find_element(By.CSS_SELECTOR, 'tr._2-RN6nWOY56sNmcDHu069P')
print(element.text)
# Out:
# 1
# Stellar Blade™
# Prepurchase
# ₩ 62,800
# ▲ 2 3

# %%
elements = driver.find_elements(By.CSS_SELECTOR, 'tr._2-RN6nWOY56sNmcDHu069P')

for element in elements:
    rank = element.find_element(By.CSS_SELECTOR, 'td._34h48M_x9S-9Q2FFPX_CcU').text
    title = element.find_element(By.CSS_SELECTOR, 'div._1n_4-zvf0n4aqGEksbgW9N').text
    price = element.find_element(By.CSS_SELECTOR, 'div._3j4dI1yA7cRfCvK8h406OB').text
    print(rank, title, f"| {price}")
# Out:
# 1 Stellar Blade™ | ₩ 62,800
# 2 PUBG: BATTLEGROUNDS | Free To Play
# 3 Lies of P | ₩ 32,400
# 4 Counter-Strike 2 | Free To Play
# 5 Lies of P: Overture Bundle | ₩ 62,200
# 6 Eternal Return | Free To Play
# 7 Lies of P: Overture | ₩ 29,800
# 8 Once Human | Free To Play
# 9 ELDEN RING NIGHTREIGN | ₩ 49,800
# 10 Mini Motorways | ₩ 10,500
# 11 Dune: Awakening | ₩ 49,900
# 12 Forza Horizon 5 | ₩ 29,950
# 13 Apex Legends™ | Free To Play
# 14 eFootball™ | Free To Play
# 15 Clair Obscur: Expedition 33 | ₩ 54,800
# 16 Limbus Company | Free To Play
# 17 Attack on Titan 2 - A.O.T.2 | ₩ 32,400
# 18 DELTARUNE | ₩ 29,800
# 19 Yu-Gi-Oh! Master Duel | Free To Play
# 20 FANTASY LIFE i: The Girl Who Steals Time | ₩ 64,800
# 21 Conqueror's Blade | Free To Play
# 22 Satisfactory | ₩ 29,400
# 23 R.E.P.O. | ₩ 11,000
# 24 GrandChase | Free To Play
# 25 The First Descendant | Free To Play
# 26 Wuthering Waves | Free To Play
# 27 Everlusting Life
# (hidden by your preferences) | Free To Play
# ...

# %%
elements = driver.find_elements(By.CSS_SELECTOR, 'tr._2-RN6nWOY56sNmcDHu069P')

for element in elements:
    rank = element.find_element(By.CSS_SELECTOR, 'td._34h48M_x9S-9Q2FFPX_CcU').text
    title = element.find_element(By.CSS_SELECTOR, 'div._1n_4-zvf0n4aqGEksbgW9N').text
    price = element.find_element(By.CSS_SELECTOR, 'div._3j4dI1yA7cRfCvK8h406OB').text
    print(rank, title, f"| {price}")
# Out:
# 1 Stellar Blade™ | ₩ 62,800
# 2 PUBG: BATTLEGROUNDS | Free To Play
# 3 Lies of P | ₩ 32,400
# 4 Counter-Strike 2 | Free To Play
# 5 Lies of P: Overture Bundle | ₩ 62,200
# 6 Eternal Return | Free To Play
# 7 Lies of P: Overture | ₩ 29,800
# 8 Once Human | Free To Play
# 9 ELDEN RING NIGHTREIGN | ₩ 49,800
# 10 Mini Motorways | ₩ 10,500
# 11 Dune: Awakening | ₩ 49,900
# 12 Forza Horizon 5 | ₩ 29,950
# 13 Apex Legends™ | Free To Play
# 14 eFootball™ | Free To Play
# 15 Clair Obscur: Expedition 33 | ₩ 54,800
# 16 Limbus Company | Free To Play
# 17 Attack on Titan 2 - A.O.T.2 | ₩ 32,400
# 18 DELTARUNE | ₩ 29,800
# 19 Yu-Gi-Oh! Master Duel | Free To Play
# 20 FANTASY LIFE i: The Girl Who Steals Time | ₩ 64,800
# 21 Conqueror's Blade | Free To Play
# 22 Satisfactory | ₩ 29,400
# 23 R.E.P.O. | ₩ 11,000
# 24 GrandChase | Free To Play
# 25 The First Descendant | Free To Play
# 26 Wuthering Waves | Free To Play
# 27 Everlusting Life
# (hidden by your preferences) | Free To Play
# ...

# %%
try:
    driver.quit()
except NameError:
    print("driver가 정의되어 있지 않습니다. 이미 종료되었거나 생성되지 않았습니다.")
# Out:
# driver가 정의되어 있지 않습니다. 이미 종료되었거나 생성되지 않았습니다.

# %%
elements = driver.find_elements(By.CSS_SELECTOR, 'tr._2-RN6nWOY56sNmcDHu069P')

for element in elements:
    rank = element.find_element(By.CSS_SELECTOR, 'td._34h48M_x9S-9Q2FFPX_CcU').text
    title = element.find_element(By.CSS_SELECTOR, 'div._1n_4-zvf0n4aqGEksbgW9N').text
    price = element.find_element(By.CSS_SELECTOR, 'div._3j4dI1yA7cRfCvK8h406OB').text
    print(rank, title, f"| {price}")
# Out:
# 1 Stellar Blade™ | ₩ 62,800
# 2 PUBG: BATTLEGROUNDS | Free To Play
# 3 Lies of P | ₩ 32,400
# 4 Counter-Strike 2 | Free To Play
# 5 Lies of P: Overture Bundle | ₩ 62,200
# 6 Eternal Return | Free To Play
# 7 Lies of P: Overture | ₩ 29,800
# 8 Once Human | Free To Play
# 9 ELDEN RING NIGHTREIGN | ₩ 49,800
# 10 Mini Motorways | ₩ 10,500
# 11 Dune: Awakening | ₩ 49,900
# 12 Forza Horizon 5 | ₩ 29,950
# 13 Apex Legends™ | Free To Play
# 14 eFootball™ | Free To Play
# 15 Clair Obscur: Expedition 33 | ₩ 54,800
# 16 Limbus Company | Free To Play
# 17 Attack on Titan 2 - A.O.T.2 | ₩ 32,400
# 18 DELTARUNE | ₩ 29,800
# 19 Yu-Gi-Oh! Master Duel | Free To Play
# 20 FANTASY LIFE i: The Girl Who Steals Time | ₩ 64,800
# 21 Conqueror's Blade | Free To Play
# 22 Satisfactory | ₩ 29,400
# 23 R.E.P.O. | ₩ 11,000
# 24 GrandChase | Free To Play
# 25 The First Descendant | Free To Play
# 26 Wuthering Waves | Free To Play
# 27 Everlusting Life
# (hidden by your preferences) | Free To Play
# ...
